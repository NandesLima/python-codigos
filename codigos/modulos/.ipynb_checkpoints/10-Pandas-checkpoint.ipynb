# %% [markdown]
# # Pandas
#
# - Biblioteca para análise de dados.
#
# - Dá ao Python a capacidade de trabalhar com dados do tipo planilha.
#
# - Permite carregar, manipular, alinhar e combinar dados rapidamente, entre outras funções.

# %%
import pandas

# %%
arquivo = "dataset.csv"

# %% [markdown]
# ### Leitura de arquivos .csv
#
# #### .read_csv() - Recebe como parâmetro o arquivo que será lido

# %%
df = pandas.read_csv(arquivo)

print(df)
# Out:
#      ID;LON;LAT;NAME;CLASS;STATE;ANNUAL;JAN;FEB;MAR;APR;MAY;JUN;JUL;AUG;SEP;OCT;NOV;DEC
# 0     30670;-68.7463;-11.0109;Brasiléia;Sede Municip...
# 1     30670;-68.7442;-11.0293;Epitaciolândia;Sede Mu...
# 2     30970;-69.5658;-10.9394;Assis Brasil;Sede Muni...
# 3     31603;-68.4973;-10.652;Xapuri;Sede Municipal;A...
# 4     31929;-67.6768;-10.5749;Capixaba;Sede Municipa...
# ...                                                 ...
# 5564  51696;-47.8115;-5.3932;Praia Norte;Sede Munici...
# 5565  51696;-47.8786;-5.3546;Sampaio;Sede Municipal;...
# 5566  52070;-48.2023;-5.2577;São Sebastião do Tocant...
# 5567  52070;-48.2275;-5.3149;Buriti do Tocantins;Sed...
# 5568  52072;-48.0357;-5.3236;Carrasco Bonito;Sede Mu...
#
# [5569 rows x 1 columns]

# %% [markdown]
# #### error_bad_lines=False - Parâmetro que faz a leitura ignorar linhas com erro

# %%
df = pandas.read_csv(arquivo, error_bad_lines=False)
print(df)
# Out:
#      ID;LON;LAT;NAME;CLASS;STATE;ANNUAL;JAN;FEB;MAR;APR;MAY;JUN;JUL;AUG;SEP;OCT;NOV;DEC
# 0     30670;-68.7463;-11.0109;Brasiléia;Sede Municip...
# 1     30670;-68.7442;-11.0293;Epitaciolândia;Sede Mu...
# 2     30970;-69.5658;-10.9394;Assis Brasil;Sede Muni...
# 3     31603;-68.4973;-10.652;Xapuri;Sede Municipal;A...
# 4     31929;-67.6768;-10.5749;Capixaba;Sede Municipa...
# ...                                                 ...
# 5564  51696;-47.8115;-5.3932;Praia Norte;Sede Munici...
# 5565  51696;-47.8786;-5.3546;Sampaio;Sede Municipal;...
# 5566  52070;-48.2023;-5.2577;São Sebastião do Tocant...
# 5567  52070;-48.2275;-5.3149;Buriti do Tocantins;Sed...
# 5568  52072;-48.0357;-5.3236;Carrasco Bonito;Sede Mu...
#
# [5569 rows x 1 columns]
# /tmp/ipykernel_391859/3994967680.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pandas.read_csv(arquivo, error_bad_lines=False)

# %% [markdown]
# #### sep="," - Parâmetro que troca o caractere de separação, por padrão é a vírgula

# %%
df = pandas.read_csv(arquivo, sep=";")
print(df)
# Out:
#          ID      LON      LAT                        NAME           CLASS  \
# 0     30670 -68.7463 -11.0109                   Brasiléia  Sede Municipal
# 1     30670 -68.7442 -11.0293              Epitaciolândia  Sede Municipal
# 2     30970 -69.5658 -10.9394                Assis Brasil  Sede Municipal
# 3     31603 -68.4973 -10.6520                      Xapuri  Sede Municipal
# 4     31929 -67.6768 -10.5749                    Capixaba  Sede Municipal
# ...     ...      ...      ...                         ...             ...
# 5564  51696 -47.8115  -5.3932                 Praia Norte  Sede Municipal
# 5565  51696 -47.8786  -5.3546                     Sampaio  Sede Municipal
# 5566  52070 -48.2023  -5.2577  São Sebastião do Tocantins  Sede Municipal
# 5567  52070 -48.2275  -5.3149         Buriti do Tocantins  Sede Municipal
# 5568  52072 -48.0357  -5.3236             Carrasco Bonito  Sede Municipal
#
#           STATE  ANNUAL   JAN   FEB   MAR   APR   MAY   JUN   JUL   AUG   SEP  \
# ...

# %% [markdown]
# ## Leitura de arquivos de excel (xls, xlsx, xlsm, xlsb e odf)

# %%
alagoas = "Nordeste/alagoas.xlsx"
bahia = "Nordeste/bahia.xlsx"
ceara = "Nordeste/ceara.xlsx"
maranhao = "Nordeste/maranhao.xlsx"
paraiba = "Nordeste/paraiba.xlsx"
pernambuco = "Nordeste/pernambuco.xlsx"
piaui = "Nordeste/piaui.xlsx"
rioGN = "Nordeste/RGN.xlsx"
sergipe = "Nordeste/sergipe.xlsx"

# %% [markdown]
# #### .read_excel() - Faz a leitura de um arquivo de excel como parâmetro

# %%
df1 = pandas.read_excel(alagoas)
df2 = pandas.read_excel(bahia)
df3 = pandas.read_excel(ceara)
df4 = pandas.read_excel(maranhao)
df5 = pandas.read_excel(paraiba)
df6 = pandas.read_excel(pernambuco)
df7 = pandas.read_excel(piaui)
df8 = pandas.read_excel(rioGN)
df9 = pandas.read_excel(sergipe)

# %% [markdown]
# ## Visualização dos arquivos
#
# #### .head() - Mostra uma quantidade x de linhas, tem como padrão 5 linhas

# %%
df.head()
# Out:
#       ID      LON      LAT            NAME           CLASS STATE  ANNUAL  \
# 0  30670 -68.7463 -11.0109       Brasiléia  Sede Municipal  ACRE    4620
# 1  30670 -68.7442 -11.0293  Epitaciolândia  Sede Municipal  ACRE    4620
# 2  30970 -69.5658 -10.9394    Assis Brasil  Sede Municipal  ACRE    4615
# 3  31603 -68.4973 -10.6520          Xapuri  Sede Municipal  ACRE    4607
# 4  31929 -67.6768 -10.5749        Capixaba  Sede Municipal  ACRE    4542
#
#     JAN   FEB   MAR   APR   MAY   JUN   JUL   AUG   SEP   OCT   NOV   DEC
# 0  4655  4653  4268  4566  3945  4079  4285  4858  5102  5105  5157  4771
# 1  4655  4653  4268  4566  3945  4079  4285  4858  5102  5105  5157  4771
# 2  4678  4661  4231  4532  3917  4026  4283  4947  5136  5092  5102  4771
# 3  4629  4586  4281  4578  3962  4125  4332  4894  5068  5071  5077  4686
# 4  4486  4527  4264  4395  3957  3983  4228  4823  5070  5138  4952  4677

# %%
df.head(10)
# Out:
#       ID      LON      LAT               NAME             CLASS STATE  ANNUAL  \
# 0  30670 -68.7463 -11.0109          Brasiléia    Sede Municipal  ACRE    4620
# 1  30670 -68.7442 -11.0293     Epitaciolândia    Sede Municipal  ACRE    4620
# 2  30970 -69.5658 -10.9394       Assis Brasil    Sede Municipal  ACRE    4615
# 3  31603 -68.4973 -10.6520             Xapuri    Sede Municipal  ACRE    4607
# 4  31929 -67.6768 -10.5749           Capixaba    Sede Municipal  ACRE    4542
# 5  32906 -67.1860 -10.3257  Plácido de Castro    Sede Municipal  ACRE    4523
# 6  33560 -67.7367 -10.1501   Senador Guiomard    Sede Municipal  ACRE    4558
# 7  33567 -67.0531 -10.0755         Acrelândia    Sede Municipal  ACRE    4515
# 8  33902 -67.8253  -9.9758         Rio Branco  Capital Estadual  ACRE    4560
# 9  34602 -67.9523  -9.8340             Bujari    Sede Municipal  ACRE    4567
#
#     JAN   FEB   MAR   APR   MAY   JUN   JUL   AUG   SEP   OCT   NOV   DEC
# ...

# %%
df.head(2)
# Out:
#       ID      LON      LAT            NAME           CLASS STATE  ANNUAL  \
# 0  30670 -68.7463 -11.0109       Brasiléia  Sede Municipal  ACRE    4620
# 1  30670 -68.7442 -11.0293  Epitaciolândia  Sede Municipal  ACRE    4620
#
#     JAN   FEB   MAR   APR   MAY   JUN   JUL   AUG   SEP   OCT   NOV   DEC
# 0  4655  4653  4268  4566  3945  4079  4285  4858  5102  5105  5157  4771
# 1  4655  4653  4268  4566  3945  4079  4285  4858  5102  5105  5157  4771

# %% [markdown]
# #### .tail() - retorna as últimas linhas, por padrão utiliza-se 5 linhas

# %%
df.tail()
# Out:
#          ID      LON     LAT                        NAME           CLASS  \
# 5564  51696 -47.8115 -5.3932                 Praia Norte  Sede Municipal
# 5565  51696 -47.8786 -5.3546                     Sampaio  Sede Municipal
# 5566  52070 -48.2023 -5.2577  São Sebastião do Tocantins  Sede Municipal
# 5567  52070 -48.2275 -5.3149         Buriti do Tocantins  Sede Municipal
# 5568  52072 -48.0357 -5.3236             Carrasco Bonito  Sede Municipal
#
#           STATE  ANNUAL   JAN   FEB   MAR   APR   MAY   JUN   JUL   AUG   SEP  \
# 5564  TOCANTINS    5064  4623  4796  4916  4949  4822  5141  5277  5720  5594
# 5565  TOCANTINS    5064  4623  4796  4916  4949  4822  5141  5277  5720  5594
# 5566  TOCANTINS    5000  4564  4725  4823  4877  4816  5153  5248  5725  5518
# 5567  TOCANTINS    5000  4564  4725  4823  4877  4816  5153  5248  5725  5518
# 5568  TOCANTINS    5029  4620  4721  4864  4938  4856  5144  5259  5704  5552
#
#        OCT   NOV   DEC
# 5564  5235  4936  4762
# ...

# %%
df.tail(10)
# Out:
#          ID      LON     LAT                        NAME           CLASS  \
# 5559  50941 -47.7721 -5.6180          Axixá do Tocantins  Sede Municipal
# 5560  50942 -47.6385 -5.6016     Sítio Novo do Tocantins  Sede Municipal
# 5561  50943 -47.5774 -5.5521     São Miguel do Tocantins  Sede Municipal
# 5562  51318 -47.8866 -5.4690              Augustinópolis  Sede Municipal
# 5563  51689 -48.5382 -5.3663                 Esperantina  Sede Municipal
# 5564  51696 -47.8115 -5.3932                 Praia Norte  Sede Municipal
# 5565  51696 -47.8786 -5.3546                     Sampaio  Sede Municipal
# 5566  52070 -48.2023 -5.2577  São Sebastião do Tocantins  Sede Municipal
# 5567  52070 -48.2275 -5.3149         Buriti do Tocantins  Sede Municipal
# 5568  52072 -48.0357 -5.3236             Carrasco Bonito  Sede Municipal
#
#           STATE  ANNUAL   JAN   FEB   MAR   APR   MAY   JUN   JUL   AUG   SEP  \
# 5559  TOCANTINS    5010  4575  4717  4785  4824  4804  5110  5279  5794  5559
# ...

# %% [markdown]
# #### .sample() - Retorna uma amostra da tabela, usa como parâmetro a quantidade de elementos da amostra

# %%
df.sample(5)
# Out:
#          ID      LON      LAT                 NAME           CLASS  \
# 3040   5378 -50.0559 -23.7930             Pinhalão  Sede Municipal
# 1006  18161 -49.3668 -16.2546           Damolândia  Sede Municipal
# 3119   6002 -52.0555 -23.1522              Atalaia  Sede Municipal
# 1105  23099 -49.1780 -14.0153            Mara Rosa  Sede Municipal
# 1847  10031 -44.0658 -20.6711  Entre Rios de Minas  Sede Municipal
#
#              STATE  ANNUAL   JAN   FEB   MAR   APR   MAY   JUN   JUL   AUG  \
# 3040        PARANÁ    4823  5720  5742  5126  4504  3582  3193  3454  4428
# 1006         GOIÁS    5273  5401  5570  5168  5153  4873  4647  4839  5817
# 3119        PARANÁ    4942  5917  5821  5323  4647  3670  3364  3563  4479
# 1105         GOIÁS    5312  5423  5510  5147  5148  4996  4777  5154  5842
# 1847  MINAS GERAIS    4872  5642  5852  4906  4523  3913  3751  3967  4927
#
#        SEP   OCT   NOV   DEC
# 3040  4625  5245  5961  6294
# 1006  5553  5521  5266  5467
# ...

# %% [markdown]
# #### .shape - Retorna a quantidade de linhas e colunas

# %%
resultado = df.shape

print(resultado)
print(type(resultado))
# Out:
# (5569, 19)
# <class 'tuple'>

# %% [markdown]
# #### .columns - Retorna o nome das colunas

# %%
resultado = df.columns

print(resultado)
print(type(resultado))
# Out:
# Index(['ID', 'LON', 'LAT', 'NAME', 'CLASS', 'STATE', 'ANNUAL', 'JAN', 'FEB',
#        'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC'],
#       dtype='object')
# <class 'pandas.core.indexes.base.Index'>

# %%
print(resultado[2])
# Out:
# LAT

# %% [markdown]
# #### .dtypes - Retorna o tipo de cada coluna

# %%
df.dtypes
# Out:
# ID          int64
# LON       float64
# LAT       float64
# NAME       object
# CLASS      object
# STATE      object
# ANNUAL      int64
# JAN         int64
# FEB         int64
# MAR         int64
# APR         int64
# MAY         int64
# JUN         int64
# JUL         int64
# AUG         int64
# SEP         int64
# OCT         int64
# NOV         int64
# DEC         int64
# dtype: object

# %% [markdown]
# ## Juntando tabelas
#
# #### .concat() - Recebe uma lista com os arquivos que quer concatenar, ficando um abaixo do outro

# %%
nordeste = pandas.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9])

nordeste.head()
# Out:
#       ID      LON      LAT                   NAME           CLASS    STATE  \
# 0  32868 -36.4343 -10.4064              Piaçabuçu  Sede Municipal  ALAGOAS
# 1  33196 -36.5822 -10.2879                 Penedo  Sede Municipal  ALAGOAS
# 2  33198 -36.3031 -10.2939          Feliz Deserto  Sede Municipal  ALAGOAS
# 3  33523 -36.8379 -10.1853  Porto Real do Colégio  Sede Municipal  ALAGOAS
# 4  33854 -36.9019 -10.1215               São Brás  Sede Municipal  ALAGOAS
#
#    ANNUAL   JAN   FEB   MAR   APR   MAY   JUN   JUL   AUG   SEP   OCT     NOV  \
# 0  5441.0  6151  6169  6059  5039  4366  4106  4158  4855  5535  6017  6358.0
# 1  5338.0  6097  5947  5891  5045  4298  4042  4110  4722  5442  5861  6297.0
# 2  5439.0  6257  6212  6051  5040  4364  4031  4142  4785  5523  6027  6346.0
# 3  5434.0  6333  6118  5996  5239  4349  4101  4151  4716  5538  5903  6349.0
# 4  5399.0  6221  6007  5932  5205  4363  4123  4185  4773  5552  5852  6291.0
#
#       DEC
# 0  6473.0
# 1  6312.0
# 2  6488.0
# ...

# %%
nordeste.tail()
# Out:
#        ID      LON         LAT                      NAME           CLASS  \
# 70  34193 -37.5619 -10026.0000   Monte Alegre de Sergipe  Sede Municipal
# 71  34198 -37.0869     -9.9701                    Gararu  Sede Municipal
# 72  34546 -37.2845     -9.9167            Porto da Folha  Sede Municipal
# 73  34905 -37.6836     -9.8066              Poço Redondo  Sede Municipal
# 74  35267 -37.7891     -9.6606  Canindé de São Francisco  Sede Municipal
#
#       STATE  ANNUAL   JAN   FEB   MAR   APR   MAY   JUN   JUL   AUG   SEP  \
# 70  SERGIPE  5299.0  6026  5899  5862  5126  4283  3971  4131  4701  5468
# 71  SERGIPE  5463.0  6289  6051  5999  5276  4383  4141  4214  4867  5694
# 72  SERGIPE  5424.0  6271  6043  5901  5202  4328  4078  4200  4783  5631
# 73  SERGIPE  5343.0  6148  5947  5916  5167  4339  3969  4082  4629  5465
# 74  SERGIPE  5432.0  6323  6069  5960  5280  4374  4000  4105  4794  5540
#
#      OCT     NOV     DEC
# 70  5697  6223.0  6200.0
# 71  5930  6379.0  6328.0
# ...

# %%
nordeste.sample(9)
# Out:
#         ID         LON      LAT                      NAME           CLASS  \
# 4    29797    -37.4612 -11.3512     Santa Luzia do Itanhy  Sede Municipal
# 166  60063    -44.0531  -2.9311          Cachoeira Grande  Sede Municipal
# 130  23849    -39.4785 -13.6869       Wenceslau Guimarães  Sede Municipal
# 20   47992    -37.3499  -6.3771        Jardim de Piranhas  Sede Municipal
# 101  41380    -35.8651  -8.1378          Riacho das Almas  Sede Municipal
# 122  42156    -36.2064  -7.9484  Santa Cruz do Capibaribe  Sede Municipal
# 411  37106    -40.9737  -9.1743                 Casa Nova  Sede Municipal
# 46   41309    -42.9521  -8.1115           Canto do Buriti  Sede Municipal
# 163  43287 -40496.0000  -7.5708                 Araripina  Sede Municipal
#
#                    STATE  ANNUAL   JAN   FEB   MAR   APR   MAY   JUN   JUL  \
# 4                SERGIPE  5347.0  6382  6121  5998  5021  4226  3956  4076
# 166             MARANHÃO  4986.0  4479  4515  4495  4441  4587  4903  5049
# ...

# %% [markdown]
# ## Alteração de dados

# %% [markdown]
# #### .rename() - Faz a renomeação de dados colocados como parâmetro
#
# #### columns={} - Parâmetro que altera o nome das colunas, utiliza dicionários, onde a chave é o nome antigo e o valor o novo nome

# %%
df = df.rename(columns={"NAME":"Cidade","STATE":"Estado","ANNUAL":"Anual"})

# %%
df.head(10)
# Out:
#       ID      LON      LAT             Cidade             CLASS Estado  Anual  \
# 0  30670 -68.7463 -11.0109          Brasiléia    Sede Municipal   ACRE   4620
# 1  30670 -68.7442 -11.0293     Epitaciolândia    Sede Municipal   ACRE   4620
# 2  30970 -69.5658 -10.9394       Assis Brasil    Sede Municipal   ACRE   4615
# 3  31603 -68.4973 -10.6520             Xapuri    Sede Municipal   ACRE   4607
# 4  31929 -67.6768 -10.5749           Capixaba    Sede Municipal   ACRE   4542
# 5  32906 -67.1860 -10.3257  Plácido de Castro    Sede Municipal   ACRE   4523
# 6  33560 -67.7367 -10.1501   Senador Guiomard    Sede Municipal   ACRE   4558
# 7  33567 -67.0531 -10.0755         Acrelândia    Sede Municipal   ACRE   4515
# 8  33902 -67.8253  -9.9758         Rio Branco  Capital Estadual   ACRE   4560
# 9  34602 -67.9523  -9.8340             Bujari    Sede Municipal   ACRE   4567
#
#     JAN   FEB   MAR   APR   MAY   JUN   JUL   AUG   SEP   OCT   NOV   DEC
# ...

# %% [markdown]
# #### .astype(tipo) - Altera o tipo de uma coluna

# %%
nordeste['ID'] = nordeste['ID'].astype('object')

nordeste.dtypes
# Out:
# ID         object
# LON       float64
# LAT       float64
# NAME       object
# CLASS      object
# STATE      object
# ANNUAL    float64
# JAN         int64
# FEB         int64
# MAR         int64
# APR         int64
# MAY         int64
# JUN         int64
# JUL         int64
# AUG         int64
# SEP         int64
# OCT         int64
# NOV       float64
# DEC       float64
# dtype: object

# %% [markdown]
# ## Análise de dados
#
# #### .describe() - Dados estatísticos gerais para todos os dados da tabela
#
# - Count: Total
# - Mean: Média
# - std: Desvio padrão
# - min: Valor mínimo
# - 25%: Primeiro quartil
# - 50%: Segundo quartil (mediana)
# - 75%: Terceiro quartil
# - max: Valores máximos

# %%
df.describe()
# Out:
#                  ID          LON          LAT        Anual          JAN  \
# count   5569.000000  5569.000000  5569.000000  5569.000000  5569.000000
# mean   22695.372957   -46.233826   -16.452789  5035.515532  5696.097684
# std    19134.809258     6.406782     8.284024   452.467930   529.359668
# min        2.000000   -72.900200   -33.687100  3594.000000  3918.000000
# 25%     6505.000000   -50.876600   -22.844600  4721.000000  5442.000000
# 50%    14733.000000   -46.521700   -18.094200  5015.000000  5785.000000
# 75%    39811.000000   -41.410900    -8.500000  5308.000000  6078.000000
# max    72220.000000   -34.815400     4.594900  6059.000000  7068.000000
#
#                FEB          MAR          APR          MAY          JUN  \
# count  5569.000000  5569.000000  5569.000000  5569.000000  5569.000000
# mean   5676.051894  5209.939666  4705.555755  4131.779673  3897.074520
# std     482.373486   461.262609   522.286076   727.417204   858.292075
# ...

# %% [markdown]
# #### Pode-se utilizar slice das colunas no dataset

# %%
df["Estado"]
# Out:
# 0            ACRE
# 1            ACRE
# 2            ACRE
# 3            ACRE
# 4            ACRE
#           ...
# 5564    TOCANTINS
# 5565    TOCANTINS
# 5566    TOCANTINS
# 5567    TOCANTINS
# 5568    TOCANTINS
# Name: Estado, Length: 5569, dtype: object

# %% [markdown]
# #### .unique() - retorna valores sem repetição

# %%
df["Estado"].unique()
# Out:
# array(['ACRE', 'ALAGOAS', 'AMAPÁ', 'AMAZONAS', 'BAHIA', 'CEARÁ',
#        'DISTRITO FEDERAL', 'ESPÍRITO SANTO', 'GOIÁS', 'MARANHÃO',
#        'MATO GROSSO', 'MATO GROSSO DO SUL', 'MINAS GERAIS', 'PARÁ',
#        'PARAÍBA', 'PARANÁ', 'PERNAMBUCO', 'PIAUÍ', 'RIO DE JANEIRO',
#        'RIO GRANDE DO NORTE', 'RIO GRANDE DO SUL', 'RONDÔNIA', 'RORAIMA',
#        'SANTA CATARINA', 'SÃO PAULO', 'SERGIPE', 'TOCANTINS'],
#       dtype=object)

# %% [markdown]
# #### .nunique() - Faz a contagem de cada elemento, sem repetição

# %%
df["Estado"].nunique()
# Out:
# 27

# %% [markdown]
# #### .mean() - Calcula a média

# %%
df["Anual"].mean()
# Out:
# 5035.515532411564

# %% [markdown]
# #### .sum() - Soma os valores da coluna

# %%
df["Anual"].sum()
# Out:
# 28042786

# %% [markdown]
# #### .std() - Calcula o desvio padrão

# %%
df["Anual"].std()
# Out:
# 452.46792983976815

# %% [markdown]
# #### .min() - Retorna o menor valor

# %%
df["Anual"].min()
# Out:
# 3594

# %% [markdown]
# #### .max() - Retorna o maior valor

# %%
df["Anual"].max()
# Out:
# 6059

# %% [markdown]
# #### .count() - Conta todas as células da coluna

# %%
df["Anual"].count()
# Out:
# 5569

# %% [markdown]
# #### .mul() - Multiplica os valores de uma coluna

# %%
df["Anual"].mul(2)
# Out:
# 0        9240
# 1        9240
# 2        9230
# 3        9214
# 4        9084
#         ...
# 5564    10128
# 5565    10128
# 5566    10000
# 5567    10000
# 5568    10058
# Name: Anual, Length: 5569, dtype: int64

# %% [markdown]
# #### .value_counts() - Conta quantas linhas tem com cada valor da coluna especificada e coloca em ordem descrescente

# %%
df["Estado"].value_counts()
# Out:
# MINAS GERAIS           853
# SÃO PAULO              645
# RIO GRANDE DO SUL      496
# BAHIA                  417
# PARANÁ                 399
# SANTA CATARINA         295
# GOIÁS                  246
# PIAUÍ                  224
# PARAÍBA                223
# MARANHÃO               217
# CEARÁ                  184
# PERNAMBUCO             184
# RIO GRANDE DO NORTE    168
# PARÁ                   144
# MATO GROSSO            141
# TOCANTINS              139
# ALAGOAS                102
# RIO DE JANEIRO          92
# MATO GROSSO DO SUL      79
# ESPÍRITO SANTO          78
# SERGIPE                 75
# AMAZONAS                62
# RONDÔNIA                52
# ACRE                    22
# AMAPÁ                   16
# RORAIMA                 15
# DISTRITO FEDERAL         1
# Name: Estado, dtype: int64

# %% [markdown]
# #### .value_counts(ascending=True) - Conta quantas linhas tem com cada valor da coluna especificada e coloca em ordem crescente

# %%
df["Estado"].value_counts(ascending=True)
# Out:
# DISTRITO FEDERAL         1
# RORAIMA                 15
# AMAPÁ                   16
# ACRE                    22
# RONDÔNIA                52
# AMAZONAS                62
# SERGIPE                 75
# ESPÍRITO SANTO          78
# MATO GROSSO DO SUL      79
# RIO DE JANEIRO          92
# ALAGOAS                102
# TOCANTINS              139
# MATO GROSSO            141
# PARÁ                   144
# RIO GRANDE DO NORTE    168
# PERNAMBUCO             184
# CEARÁ                  184
# MARANHÃO               217
# PARAÍBA                223
# PIAUÍ                  224
# GOIÁS                  246
# SANTA CATARINA         295
# PARANÁ                 399
# BAHIA                  417
# RIO GRANDE DO SUL      496
# SÃO PAULO              645
# MINAS GERAIS           853
# Name: Estado, dtype: int64

# %% [markdown]
# #### .loc[] - Faz um filtro de busca, dentro do cochetes utiliza-se um df["coluna"] e utiliza-se um operador lógico comparando com o que se quer filtrar.

# %%
ceara = df.loc[df["Estado"] == "CEARÁ"]

ceara.head(10)
# Out:
#         ID      LON     LAT       Cidade           CLASS Estado  Anual   JAN  \
# 619  42518 -39.0722 -7.8291    Penaforte  Sede Municipal  CEARÁ   5743  5999
# 620  42909 -39.0057 -7.6864         Jati  Sede Municipal  CEARÁ   5712  5953
# 621  43299 -39.2767 -7.5855       Jardim  Sede Municipal  CEARÁ   5709  5968
# 622  43692 -39.1162 -7.5338    Porteiras  Sede Municipal  CEARÁ   5764  5954
# 623  43694 -38.9864 -7.4890  Brejo Santo  Sede Municipal  CEARÁ   5869  6099
# 624  44086 -39.0485 -7.3609      Abaiara  Sede Municipal  CEARÁ   5903  6031
# 625  44089 -38.7711 -7.3864      Mauriti  Sede Municipal  CEARÁ   5886  6053
# 626  44465 -40.4590 -7.2842      Salitre  Sede Municipal  CEARÁ   5713  5456
# 627  44476 -39.3088 -7.3008     Barbalha  Sede Municipal  CEARÁ   5831  5905
# 628  44480 -38.9421 -7.3008     Milagres  Sede Municipal  CEARÁ   5891  6025
#
#       FEB   MAR   APR   MAY   JUN   JUL   AUG   SEP   OCT   NOV   DEC
# ...

# %%
alagoas = df.loc[df["Estado"] == "ALAGOAS"]
alagoas.head(10)
# Out:
#        ID      LON      LAT                 Cidade           CLASS   Estado  \
# 22  32868 -36.4343 -10.4064              Piaçabuçu  Sede Municipal  ALAGOAS
# 23  33196 -36.5822 -10.2879                 Penedo  Sede Municipal  ALAGOAS
# 24  33198 -36.3031 -10.2939          Feliz Deserto  Sede Municipal  ALAGOAS
# 25  33523 -36.8379 -10.1853  Porto Real do Colégio  Sede Municipal  ALAGOAS
# 26  33854 -36.9019 -10.1215               São Brás  Sede Municipal  ALAGOAS
# 27  33855 -36.8133 -10.0571     Olho d'Água Grande  Sede Municipal  ALAGOAS
# 28  33857 -36.6571 -10.1284            Igreja Nova  Sede Municipal  ALAGOAS
# 29  33862 -36.1720 -10.1281               Coruripe  Sede Municipal  ALAGOAS
# 30  34198 -37.0025  -9.9628                 Traipu  Sede Municipal  ALAGOAS
# 31  34201 -36.7929  -9.9559           Campo Grande  Sede Municipal  ALAGOAS
#
#     Anual   JAN   FEB   MAR   APR   MAY   JUN   JUL   AUG   SEP   OCT   NOV  \
# ...

# %% [markdown]
# #### Uso de mais de um filtro, é só utilizar mais de um .loc[]

# %%
df.loc[df["Estado"] == "ALAGOAS"].loc[df['JAN']>=6000]
# Out:
#         ID      LON      LAT                   Cidade             CLASS  \
# 22   32868 -36.4343 -10.4064                Piaçabuçu    Sede Municipal
# 23   33196 -36.5822 -10.2879                   Penedo    Sede Municipal
# 24   33198 -36.3031 -10.2939            Feliz Deserto    Sede Municipal
# 25   33523 -36.8379 -10.1853    Porto Real do Colégio    Sede Municipal
# 26   33854 -36.9019 -10.1215                 São Brás    Sede Municipal
# 27   33855 -36.8133 -10.0571       Olho d'Água Grande    Sede Municipal
# 29   33862 -36.1720 -10.1281                 Coruripe    Sede Municipal
# 30   34198 -37.0025  -9.9628                   Traipu    Sede Municipal
# 32   34208 -36.0145 -10.0137          Jequiá da Praia    Sede Municipal
# 33   34550 -36.8319  -9.8845        Girau do Ponciano    Sede Municipal
# 35   34553 -36.5501  -9.9319            São Sebastião    Sede Municipal
# 38   34909 -37.2773  -9.8232               Belo Monte    Sede Municipal
# ...

# %%
df.loc[(df["Estado"] == "ALAGOAS") & (df['JAN']>=6000)]
# Out:
#         ID      LON      LAT                   Cidade             CLASS  \
# 22   32868 -36.4343 -10.4064                Piaçabuçu    Sede Municipal
# 23   33196 -36.5822 -10.2879                   Penedo    Sede Municipal
# 24   33198 -36.3031 -10.2939            Feliz Deserto    Sede Municipal
# 25   33523 -36.8379 -10.1853    Porto Real do Colégio    Sede Municipal
# 26   33854 -36.9019 -10.1215                 São Brás    Sede Municipal
# 27   33855 -36.8133 -10.0571       Olho d'Água Grande    Sede Municipal
# 29   33862 -36.1720 -10.1281                 Coruripe    Sede Municipal
# 30   34198 -37.0025  -9.9628                   Traipu    Sede Municipal
# 32   34208 -36.0145 -10.0137          Jequiá da Praia    Sede Municipal
# 33   34550 -36.8319  -9.8845        Girau do Ponciano    Sede Municipal
# 35   34553 -36.5501  -9.9319            São Sebastião    Sede Municipal
# 38   34909 -37.2773  -9.8232               Belo Monte    Sede Municipal
# ...

# %% [markdown]
# #### .groupby() - Faz o agrupamento de dados
#
# - Escolhe por qual coluna quer fazer o agrupamento, dentro do parênteses.
# - Utiliza-se um colchetes com o parÂmetro que será utilizado como filtro.
# - Usa um método que vai gerar a interação desejada

# %%
# Contagem das cidades de cada estado
df.groupby('Estado')['Cidade'].nunique()
# Out:
# Estado
# ACRE                    22
# ALAGOAS                102
# AMAPÁ                   16
# AMAZONAS                62
# BAHIA                  417
# CEARÁ                  184
# DISTRITO FEDERAL         1
# ESPÍRITO SANTO          78
# GOIÁS                  246
# MARANHÃO               217
# MATO GROSSO            141
# MATO GROSSO DO SUL      79
# MINAS GERAIS           853
# PARANÁ                 399
# PARAÍBA                223
# PARÁ                   144
# PERNAMBUCO             184
# PIAUÍ                  224
# RIO DE JANEIRO          92
# RIO GRANDE DO NORTE    168
# RIO GRANDE DO SUL      496
# RONDÔNIA                52
# RORAIMA                 15
# SANTA CATARINA         295
# SERGIPE                 75
# SÃO PAULO              645
# TOCANTINS              139
# Name: Cidade, dtype: int64

# %%
# Média de irradiação solar anual por estado
df.groupby("Estado")["Anual"].mean()
# Out:
# Estado
# ACRE                   4601.818182
# ALAGOAS                5326.637255
# AMAPÁ                  4705.062500
# AMAZONAS               4492.854839
# BAHIA                  5245.299760
# CEARÁ                  5665.027174
# DISTRITO FEDERAL       5252.000000
# ESPÍRITO SANTO         4820.974359
# GOIÁS                  5297.865854
# MARANHÃO               5201.059908
# MATO GROSSO            5025.929078
# MATO GROSSO DO SUL     4991.772152
# MINAS GERAIS           4998.922626
# PARANÁ                 4746.513784
# PARAÍBA                5649.008969
# PARÁ                   4805.798611
# PERNAMBUCO             5427.260870
# PIAUÍ                  5717.397321
# RIO DE JANEIRO         4719.217391
# RIO GRANDE DO NORTE    5742.351190
# RIO GRANDE DO SUL      4503.439516
# RONDÔNIA               4603.134615
# RORAIMA                4898.600000
# SANTA CATARINA         4304.735593
# SERGIPE                5315.506667
# SÃO PAULO              4916.093023
# ...

# %%
# Desvio padrão da irradiação solar anual por estado
df.groupby("Estado")["Anual"].std()
# Out:
# Estado
# ACRE                    62.953223
# ALAGOAS                131.843726
# AMAPÁ                  112.161472
# AMAZONAS                84.558418
# BAHIA                  352.382767
# CEARÁ                  162.781708
# DISTRITO FEDERAL              NaN
# ESPÍRITO SANTO         110.694616
# GOIÁS                   90.849653
# MARANHÃO               209.646111
# MATO GROSSO            163.966445
# MATO GROSSO DO SUL     119.405466
# MINAS GERAIS           296.790668
# PARANÁ                 264.165138
# PARAÍBA                275.944324
# PARÁ                   150.693668
# PERNAMBUCO             239.203088
# PIAUÍ                  102.363277
# RIO DE JANEIRO         164.256421
# RIO GRANDE DO NORTE    201.679776
# RIO GRANDE DO SUL      143.839783
# RONDÔNIA                78.463437
# RORAIMA                167.538396
# SANTA CATARINA         258.684975
# SERGIPE                 86.881929
# SÃO PAULO              288.128412
# TOCANTINS              175.385565
# ...

# %% [markdown]
# #### .isnull() - Verifica se existe valores nulos

# %%
nordeste.isnull()
# Out:
#        ID    LON    LAT   NAME  CLASS  STATE  ANNUAL    JAN    FEB    MAR  \
# 0   False  False  False  False  False  False   False  False  False  False
# 1   False  False  False  False  False  False   False  False  False  False
# 2   False  False  False  False  False  False   False  False  False  False
# 3   False  False  False  False  False  False   False  False  False  False
# 4   False  False  False  False  False  False   False  False  False  False
# ..    ...    ...    ...    ...    ...    ...     ...    ...    ...    ...
# 70  False  False  False  False  False  False   False  False  False  False
# 71  False  False  False  False  False  False   False  False  False  False
# 72  False  False  False  False  False  False   False  False  False  False
# 73  False  False  False  False  False  False   False  False  False  False
# 74  False  False  False  False  False  False   False  False  False  False
#
#       APR    MAY    JUN    JUL    AUG    SEP    OCT    NOV    DEC
# ...

# %% [markdown]
# #### .isnull().sum() - Verifica a quantidade de nulos

# %%
nordeste.isnull().sum()
# Out:
# ID        0
# LON       0
# LAT       0
# NAME      0
# CLASS     0
# STATE     0
# ANNUAL    3
# JAN       0
# FEB       0
# MAR       0
# APR       0
# MAY       0
# JUN       0
# JUL       0
# AUG       0
# SEP       0
# OCT       0
# NOV       3
# DEC       3
# dtype: int64

# %% [markdown]
# #### .fillna() - Recebe como parâmetro um valor que será colocado em espaços nulos
#
# - inplace=True, parâmetro que substitui o objeto em memória, ou seja salvas modificações

# %%
nordeste["ANNUAL"].fillna(nordeste["ANNUAL"].mean(), inplace=True)

nordeste.isnull().sum()
# Out:
# ID        0
# LON       0
# LAT       0
# NAME      0
# CLASS     0
# STATE     0
# ANNUAL    0
# JAN       0
# FEB       0
# MAR       0
# APR       0
# MAY       0
# JUN       0
# JUL       0
# AUG       0
# SEP       0
# OCT       0
# NOV       3
# DEC       3
# dtype: int64

# %%
nordeste["DEC"].fillna(5700, inplace=True)

nordeste.isnull().sum()
# Out:
# ID        0
# LON       0
# LAT       0
# NAME      0
# CLASS     0
# STATE     0
# ANNUAL    0
# JAN       0
# FEB       0
# MAR       0
# APR       0
# MAY       0
# JUN       0
# JUL       0
# AUG       0
# SEP       0
# OCT       0
# NOV       3
# DEC       0
# dtype: int64

# %% [markdown]
# #### .dropna() - Remove linhas com valores faltantes
#
# - inplace=True, parâmetro que substitui o objeto em memória, ou seja salvas modificações
#
# - subset=[coluna], parâmetro para apagar linhas com valores nulos com base em uma coluna
#
# - how='all', parâmetro que remove linhas que todas suas colunas estejam como nulas

# %%
nordeste.dropna(subset=['NOV'], inplace=True)

nordeste.isnull().sum()
# Out:
# ID        0
# LON       0
# LAT       0
# NAME      0
# CLASS     0
# STATE     0
# ANNUAL    0
# JAN       0
# FEB       0
# MAR       0
# APR       0
# MAY       0
# JUN       0
# JUL       0
# AUG       0
# SEP       0
# OCT       0
# NOV       0
# DEC       0
# dtype: int64

# %%
nordeste.dropna(how='all', inplace=True)

nordeste.isnull().sum()
# Out:
# ID        0
# LON       0
# LAT       0
# NAME      0
# CLASS     0
# STATE     0
# ANNUAL    0
# JAN       0
# FEB       0
# MAR       0
# APR       0
# MAY       0
# JUN       0
# JUL       0
# AUG       0
# SEP       0
# OCT       0
# NOV       0
# DEC       0
# dtype: int64

# %% [markdown]
# #### .nlargest() - Utiliza dois parâmetros, o primeiro é a quantidade de linhas que ele deve retornar, o segundo é a coluna que vai ser analisada. No final é retornado os que tiverem os maiores valores da coluna indicada.

# %%
df.nlargest(5, "Anual")
# Out:
#          ID      LON     LAT                    Cidade           CLASS  \
# 2693  46050 -38.3223 -6.9118               Nazarezinho  Sede Municipal
# 2714  46441 -38.2280 -6.7593                     Sousa  Sede Municipal
# 2713  46440 -38.3486 -6.8458               Marizópolis  Sede Municipal
# 2694  46052 -38.1625 -6.9369  São José da Lagoa Tapada  Sede Municipal
# 2652  45271 -38.1684 -7.0922                    Aguiar  Sede Municipal
#
#        Estado  Anual   JAN   FEB   MAR   APR   MAY   JUN   JUL   AUG   SEP  \
# 2693  PARAÍBA   6059  6192  6189  6208  5860  5316  5058  5321  6036  6545
# 2714  PARAÍBA   6052  6195  6188  6201  5874  5331  5045  5292  6036  6496
# 2713  PARAÍBA   6046  6190  6149  6190  5828  5302  5047  5308  6051  6512
# 2694  PARAÍBA   6042  6121  6145  6189  5888  5347  5050  5279  6061  6549
# 2652  PARAÍBA   6041  6327  6166  6228  5897  5270  4904  5192  5930  6553
#
#        OCT   NOV   DEC
# 2693  6687  6815  6482
# 2714  6691  6834  6434
# ...

# %% [markdown]
# #### .nsmallest() - Utiliza dois parâmetros, o primeiro é a quantidade de linhas que ele deve retornar, o segundo é a coluna que vai ser analisada. No final é retornado os que tiverem os menores valores da coluna indicada.

# %%
df.nsmallest(7, "FEB")
# Out:
#         ID      LON     LAT                   Cidade             CLASS  \
# 135  70034 -50.9091  1.5062          Tartarugalzinho    Sede Municipal
# 136  70357 -50.7839  1.7448                 Pracuúba    Sede Municipal
# 133  68955 -51.1799  0.8569           Ferreira Gomes    Sede Municipal
# 132  68946 -52.0040  0.9010           Serra do Navio    Sede Municipal
# 134  69144 -50.7980  0.9690                   Cutias    Sede Municipal
# 179  59297 -60.0221 -3.1194                   Manaus  Capital Estadual
# 131  68759 -51.9507  0.7771  Pedra Branca do Amapari    Sede Municipal
#
#        Estado  Anual   JAN   FEB   MAR   APR   MAY   JUN   JUL   AUG   SEP  \
# 135     AMAPÁ   4595  4138  3916  3941  3952  4347  4624  4869  5254  5402
# 136     AMAPÁ   4647  4206  3954  3922  3933  4345  4553  4863  5247  5537
# 133     AMAPÁ   4688  4230  4004  4047  4089  4428  4684  4888  5357  5477
# 132     AMAPÁ   4575  4178  4009  4103  4175  4383  4481  4676  5028  5330
# ...

# %% [markdown]
# #### .sort_values() - Retorna o conjunto de dados ordenado pela coluna escolhida

# %%
df.sort_values("Anual")
# Out:
#          ID      LON      LAT                    Cidade           CLASS  \
# 4709   3835 -48.8524 -26.0297                    Garuva  Sede Municipal
# 2868   4126 -48.8350 -25.4748                  Morretes  Sede Municipal
# 4692   3620 -49.0745 -26.4121                 Schroeder  Sede Municipal
# 4699   3674 -48.8491 -26.3050                 Joinville  Sede Municipal
# 2851   4001 -48.5115 -25.6740          Pontal do Paraná  Sede Municipal
# ...     ...      ...      ...                       ...             ...
# 2652  45271 -38.1684  -7.0922                    Aguiar  Sede Municipal
# 2694  46052 -38.1625  -6.9369  São José da Lagoa Tapada  Sede Municipal
# 2713  46440 -38.3486  -6.8458               Marizópolis  Sede Municipal
# 2714  46441 -38.2280  -6.7593                     Sousa  Sede Municipal
# 2693  46050 -38.3223  -6.9118               Nazarezinho  Sede Municipal
#
#               Estado  Anual   JAN   FEB   MAR   APR   MAY   JUN   JUL   AUG  \
# ...

# %%
df.sort_values("Anual").head(5)
# Out:
#         ID      LON      LAT            Cidade           CLASS  \
# 4709  3835 -48.8524 -26.0297            Garuva  Sede Municipal
# 2868  4126 -48.8350 -25.4748          Morretes  Sede Municipal
# 4692  3620 -49.0745 -26.4121         Schroeder  Sede Municipal
# 4699  3674 -48.8491 -26.3050         Joinville  Sede Municipal
# 2851  4001 -48.5115 -25.6740  Pontal do Paraná  Sede Municipal
#
#               Estado  Anual   JAN   FEB   MAR   APR   MAY   JUN   JUL   AUG  \
# 4709  SANTA CATARINA   3594  4714  4534  3955  3327  2844  2436  2528  3238
# 2868          PARANÁ   3785  4998  4849  4180  3535  2929  2557  2623  3348
# 4692  SANTA CATARINA   3787  5017  4791  4237  3523  2928  2456  2563  3275
# 4699  SANTA CATARINA   3787  5046  4844  4241  3519  2926  2449  2517  3184
# 2851          PARANÁ   3802  5120  5032  4266  3527  2931  2469  2512  3200
#
#        SEP   OCT   NOV   DEC
# 4709  3066  3457  4351  4683
# 2868  3182  3660  4557  4997
# 4692  3198  3704  4726  5022
# ...

# %% [markdown]
# #### ascending=False, parâmetro que faz com que a ordem seja do menor para o maior

# %%
df.sort_values("Anual", ascending=True).head(10)
# Out:
#         ID      LON      LAT            Cidade           CLASS  \
# 4709  3835 -48.8524 -26.0297            Garuva  Sede Municipal
# 2868  4126 -48.8350 -25.4748          Morretes  Sede Municipal
# 4692  3620 -49.0745 -26.4121         Schroeder  Sede Municipal
# 4699  3674 -48.8491 -26.3050         Joinville  Sede Municipal
# 2851  4001 -48.5115 -25.6740  Pontal do Paraná  Sede Municipal
# 2889  4192 -48.7195 -25.4391          Antonina  Sede Municipal
# 2838  3946 -48.5494 -25.8241          Matinhos  Sede Municipal
# 4750  5315 -46.4244 -23.8916           Cubatão  Sede Municipal
# 4656  3461 -49.2723 -26.7403    Rio dos Cedros  Sede Municipal
# 4657  3462 -49.1789 -26.7388          Pomerode  Sede Municipal
#
#               Estado  Anual   JAN   FEB   MAR   APR   MAY   JUN   JUL   AUG  \
# 4709  SANTA CATARINA   3594  4714  4534  3955  3327  2844  2436  2528  3238
# 2868          PARANÁ   3785  4998  4849  4180  3535  2929  2557  2623  3348
# ...

# %% [markdown]
# ## Criando colunas
#
# - Para criar novas colunas, precisa-se apenas declarar a variável com um nome de coluna ainda não utilizado e atribuir valores

# %%
nordeste['Total_anual'] = nordeste['JAN'] + nordeste['FEB'] + nordeste['MAR'] + nordeste['APR'] + nordeste['MAY'] + nordeste['JUN'] + nordeste['JUL'] + nordeste['AUG'] + nordeste['SEP'] + nordeste['OCT'] + nordeste['NOV'] + nordeste['DEC']

nordeste.head()
# Out:
#       ID      LON      LAT                   NAME           CLASS    STATE  \
# 0  32868 -36.4343 -10.4064              Piaçabuçu  Sede Municipal  ALAGOAS
# 1  33196 -36.5822 -10.2879                 Penedo  Sede Municipal  ALAGOAS
# 2  33198 -36.3031 -10.2939          Feliz Deserto  Sede Municipal  ALAGOAS
# 3  33523 -36.8379 -10.1853  Porto Real do Colégio  Sede Municipal  ALAGOAS
# 4  33854 -36.9019 -10.1215               São Brás  Sede Municipal  ALAGOAS
#
#    ANNUAL   JAN   FEB   MAR   APR   MAY   JUN   JUL   AUG   SEP   OCT     NOV  \
# 0  5441.0  6151  6169  6059  5039  4366  4106  4158  4855  5535  6017  6358.0
# 1  5338.0  6097  5947  5891  5045  4298  4042  4110  4722  5442  5861  6297.0
# 2  5439.0  6257  6212  6051  5040  4364  4031  4142  4785  5523  6027  6346.0
# 3  5434.0  6333  6118  5996  5239  4349  4101  4151  4716  5538  5903  6349.0
# 4  5399.0  6221  6007  5932  5205  4363  4123  4185  4773  5552  5852  6291.0
#
#       DEC  Total_anual
# ...

# %%
nordeste['Media_S1'] = (nordeste['JAN'] + nordeste['FEB'] + nordeste['MAR'] + nordeste['APR'] + nordeste['MAY'] + nordeste['JUN'])/6

nordeste.head()
# Out:
#       ID      LON      LAT                   NAME           CLASS    STATE  \
# 0  32868 -36.4343 -10.4064              Piaçabuçu  Sede Municipal  ALAGOAS
# 1  33196 -36.5822 -10.2879                 Penedo  Sede Municipal  ALAGOAS
# 2  33198 -36.3031 -10.2939          Feliz Deserto  Sede Municipal  ALAGOAS
# 3  33523 -36.8379 -10.1853  Porto Real do Colégio  Sede Municipal  ALAGOAS
# 4  33854 -36.9019 -10.1215               São Brás  Sede Municipal  ALAGOAS
#
#    ANNUAL   JAN   FEB   MAR  ...   MAY   JUN   JUL   AUG   SEP   OCT     NOV  \
# 0  5441.0  6151  6169  6059  ...  4366  4106  4158  4855  5535  6017  6358.0
# 1  5338.0  6097  5947  5891  ...  4298  4042  4110  4722  5442  5861  6297.0
# 2  5439.0  6257  6212  6051  ...  4364  4031  4142  4785  5523  6027  6346.0
# 3  5434.0  6333  6118  5996  ...  4349  4101  4151  4716  5538  5903  6349.0
# 4  5399.0  6221  6007  5932  ...  4363  4123  4185  4773  5552  5852  6291.0
#
#       DEC  Total_anual     Media_S1
# ...

# %%
nordeste['Media_S2'] = (nordeste['JUL'] + nordeste['AUG'] + nordeste['SEP'] + nordeste['OCT'] + nordeste['NOV'] + nordeste['DEC'])/6

nordeste.head()
# Out:
#       ID      LON      LAT                   NAME           CLASS    STATE  \
# 0  32868 -36.4343 -10.4064              Piaçabuçu  Sede Municipal  ALAGOAS
# 1  33196 -36.5822 -10.2879                 Penedo  Sede Municipal  ALAGOAS
# 2  33198 -36.3031 -10.2939          Feliz Deserto  Sede Municipal  ALAGOAS
# 3  33523 -36.8379 -10.1853  Porto Real do Colégio  Sede Municipal  ALAGOAS
# 4  33854 -36.9019 -10.1215               São Brás  Sede Municipal  ALAGOAS
#
#    ANNUAL   JAN   FEB   MAR  ...   JUN   JUL   AUG   SEP   OCT     NOV  \
# 0  5441.0  6151  6169  6059  ...  4106  4158  4855  5535  6017  6358.0
# 1  5338.0  6097  5947  5891  ...  4042  4110  4722  5442  5861  6297.0
# 2  5439.0  6257  6212  6051  ...  4031  4142  4785  5523  6027  6346.0
# 3  5434.0  6333  6118  5996  ...  4101  4151  4716  5538  5903  6349.0
# 4  5399.0  6221  6007  5932  ...  4123  4185  4773  5552  5852  6291.0
#
#       DEC  Total_anual     Media_S1     Media_S2
# ...

# %%
nordeste.groupby("STATE")["ANNUAL"].std()
# Out:
# STATE
# ALAGOAS                133.323503
# BAHIA                  352.382767
# CEARÁ                  162.781708
# MARANHÃO               209.646111
# PARAÍBA                275.944324
# PERNAMBUCO             238.526406
# PIAUÍ                  100.745570
# RIO GRANDE DO NORTE    201.679776
# SERGIPE                 86.881929
# Name: ANNUAL, dtype: float64

# %% [markdown]
# ## Excluindo colunas

# %%
del nordeste['ID']
del nordeste['LON']
del nordeste['LAT']
del nordeste ['CLASS']

# %%
nordeste.tail()
# Out:
#                         NAME    STATE  ANNUAL   JAN   FEB   MAR   APR   MAY  \
# 70   Monte Alegre de Sergipe  SERGIPE  5299.0  6026  5899  5862  5126  4283
# 71                    Gararu  SERGIPE  5463.0  6289  6051  5999  5276  4383
# 72            Porto da Folha  SERGIPE  5424.0  6271  6043  5901  5202  4328
# 73              Poço Redondo  SERGIPE  5343.0  6148  5947  5916  5167  4339
# 74  Canindé de São Francisco  SERGIPE  5432.0  6323  6069  5960  5280  4374
#
#      JUN   JUL   AUG   SEP   OCT     NOV     DEC  Total_anual     Media_S1  \
# 70  3971  4131  4701  5468  5697  6223.0  6200.0      63587.0  5194.500000
# 71  4141  4214  4867  5694  5930  6379.0  6328.0      65551.0  5356.500000
# 72  4078  4200  4783  5631  5887  6439.0  6322.0      65085.0  5303.833333
# 73  3969  4082  4629  5465  5801  6345.0  6311.0      64119.0  5247.666667
# 74  4000  4105  4794  5540  5905  6427.0  6402.0      65179.0  5334.333333
#
#        Media_S2
# 70  5403.333333
# 71  5568.666667
# ...

# %% [markdown]
# ## Trabalhando com datas

# %%
arquivo = 'global.xlsx'
df = pandas.read_excel(arquivo)
del df['ID']
df.head()
# Out:
#            Cidade Estado Região       Data  ANNUAL
# 0       Brasiléia   ACRE  NORTE 2022-11-30  4620.0
# 1  Epitaciolândia   ACRE  NORTE 2022-12-01  4620.0
# 2    Assis Brasil   ACRE  NORTE 2022-11-20  4615.0
# 3          Xapuri   ACRE  NORTE 2022-11-21  4607.0
# 4        Capixaba   ACRE  NORTE 2022-11-22  4542.0

# %%
# A data está no formato datetime como padrão
df.dtypes
# Out:
# Cidade            object
# Estado            object
# Região            object
# Data      datetime64[ns]
# ANNUAL           float64
# dtype: object

# %%
# Transformar a coluna de data em tipo inteiro
df['Data'] = df['Data'].astype('int64')

df.dtypes
# Out:
# Cidade     object
# Estado     object
# Região     object
# Data        int64
# ANNUAL    float64
# dtype: object

# %%
df.head()
# Out:
#            Cidade Estado Região                 Data  ANNUAL
# 0       Brasiléia   ACRE  NORTE  1669766400000000000  4620.0
# 1  Epitaciolândia   ACRE  NORTE  1669852800000000000  4620.0
# 2    Assis Brasil   ACRE  NORTE  1668902400000000000  4615.0
# 3          Xapuri   ACRE  NORTE  1668988800000000000  4607.0
# 4        Capixaba   ACRE  NORTE  1669075200000000000  4542.0

# %% [markdown]
# #### .to_datetime() - Transforma uma determinada coluna no formato datetime

# %%
df['Data'] = pandas.to_datetime(df['Data'])

df.head()
# Out:
#            Cidade Estado Região       Data  ANNUAL
# 0       Brasiléia   ACRE  NORTE 2022-11-30  4620.0
# 1  Epitaciolândia   ACRE  NORTE 2022-12-01  4620.0
# 2    Assis Brasil   ACRE  NORTE 2022-11-20  4615.0
# 3          Xapuri   ACRE  NORTE 2022-11-21  4607.0
# 4        Capixaba   ACRE  NORTE 2022-11-22  4542.0

# %% [markdown]
# #### .dt.year - Utiliza apenas o ano da data

# %%
df['Data'].dt.year
# Out:
# 0       2022
# 1       2022
# 2       2022
# 3       2022
# 4       2022
#         ...
# 5564    2022
# 5565    2022
# 5566    2022
# 5567    2022
# 5568    2022
# Name: Data, Length: 5569, dtype: int64

# %%
df['Data'].dt.year.unique()
# Out:
# array([2022, 2023, 2021])

# %%
df.groupby(df['Data'].dt.year)['ANNUAL'].mean()
# Out:
# Data
# 2021    5494.333333
# 2022    5056.818020
# 2023    4819.300990
# Name: ANNUAL, dtype: float64

# %%
df.loc[df["Data"].dt.year == 2023].loc[df['ANNUAL'] >= 5300]
# Out:
#                         Cidade       Estado        Região       Data  ANNUAL
# 556                      Barra        BAHIA      NORDESTE 2023-01-02  5969.0
# 557                    Central        BAHIA      NORDESTE 2023-01-03  5836.0
# 560       Formosa do Rio Preto        BAHIA      NORDESTE 2023-01-06  5789.0
# 561       Santa Rita de Cássia        BAHIA      NORDESTE 2023-01-07  5865.0
# 562          Itaguaçu da Bahia        BAHIA      NORDESTE 2023-01-08  6006.0
# 563                    Jussara        BAHIA      NORDESTE 2023-01-09  5846.0
# 564                 Ourolândia        BAHIA      NORDESTE 2023-01-10  5419.0
# 568                     Tucano        BAHIA      NORDESTE 2023-01-14  5325.0
# 572                Xique-Xique        BAHIA      NORDESTE 2023-01-18  6021.0
# 576                   Mansidão        BAHIA      NORDESTE 2023-01-22  5809.0
# 577                 Buritirama        BAHIA      NORDESTE 2023-01-23  5901.0
# ...

# %% [markdown]
# #### .dt.month - Utiliza apenas o mês da data

# %%
df.groupby(df['Data'].dt.month)['ANNUAL'].std()
# Out:
# Data
# 1     452.426330
# 2     387.224806
# 3     476.629603
# 4     240.355444
# 5     279.249438
# 6     377.238303
# 7     546.512390
# 8     434.663934
# 9     435.027911
# 10    450.693495
# 11    378.043657
# 12    378.259207
# Name: ANNUAL, dtype: float64

# %% [markdown]
# #### .dt.day - Utiliza apenas o dia da data

# %%
df.loc[df["Data"].dt.day >= 30]
# Out:
#                   Cidade     Estado    Região       Data  ANNUAL
# 0              Brasiléia       ACRE     NORTE 2022-11-30  4620.0
# 12                Jordão       ACRE     NORTE 2022-11-30  4640.0
# 13        Sena Madureira       ACRE     NORTE 2022-10-31  4539.0
# 50                Anadia    ALAGOAS  NORDESTE 2022-04-30  5234.0
# 80    Santana do Ipanema    ALAGOAS  NORDESTE 2022-05-30  5462.0
# ...                  ...        ...       ...        ...     ...
# 5502            Rio Sono  TOCANTINS     NORTE 2022-09-30  5308.0
# 5532          Pau D'Arco  TOCANTINS     NORTE 2022-10-30  5021.0
# 5533          Filadélfia  TOCANTINS     NORTE 2022-10-31  5178.0
# 5546             Xambioá  TOCANTINS     NORTE 2022-10-30  5002.0
# 5547           Riachinho  TOCANTINS     NORTE 2022-10-31  5001.0
#
# [290 rows x 5 columns]

# %% [markdown]
# #### .dt.quarter - Utiliza apenas o trimestre da data

# %%
df.loc[df["Data"].dt.quarter == 3]
# Out:
#                         Cidade     Estado    Região       Data  ANNUAL
# 112                     Canapi    ALAGOAS  NORDESTE 2022-07-01  5531.0
# 113              Joaquim Gomes    ALAGOAS  NORDESTE 2022-07-02  4983.0
# 114                Porto Calvo    ALAGOAS  NORDESTE 2022-07-03  5350.0
# 115                Japaratinga    ALAGOAS  NORDESTE 2022-07-04  5518.0
# 116           São José da Laje    ALAGOAS  NORDESTE 2022-07-05  5080.0
# ...                        ...        ...       ...        ...     ...
# 5498                 Miranorte  TOCANTINS     NORTE 2022-09-26  5186.0
# 5499                   Caseara  TOCANTINS     NORTE 2022-09-27  5118.0
# 5500  Dois Irmãos do Tocantins  TOCANTINS     NORTE 2022-09-28  5135.0
# 5501              Rio dos Bois  TOCANTINS     NORTE 2022-09-29  5156.0
# 5502                  Rio Sono  TOCANTINS     NORTE 2022-09-30  5308.0
#
# [1651 rows x 5 columns]

# %% [markdown]
# #### Calculando a diferença de dias

# %%
df['diferença_dias'] = df['Data'] - df['Data'].min()

df.sample(5)
# Out:
#                    Cidade        Estado   Região       Data  ANNUAL  \
# 4819            Paraibuna     SÃO PAULO  SUDESTE 2022-12-13  4660.0
# 1773  Santa Cruz de Minas  MINAS GERAIS  SUDESTE 2022-11-12  4806.0
# 1695           Cabo Verde  MINAS GERAIS  SUDESTE 2022-08-26  4846.0
# 5110               Pongaí     SÃO PAULO  SUDESTE 2022-11-28  5138.0
# 2115             Joanésia  MINAS GERAIS  SUDESTE 2022-10-29  4913.0
#
#      diferença_dias
# 4819       349 days
# 1773       318 days
# 1695       240 days
# 5110       334 days
# 2115       304 days

# %%
# 15 de março de 2023
data = df.loc[(df['Data'].dt.day == 15) & (df['Data'].dt.month == 3)].loc[df['Data'].dt.year == 2023]

data.head()
# Out:
#                   Cidade             Estado Região       Data  ANNUAL  \
# 3042  Santana do Itararé             PARANÁ    SUL 2023-03-15  4768.0
# 4109       Antônio Prado  RIO GRANDE DO SUL    SUL 2023-03-15  4427.0
# 4575           Tunápolis     SANTA CATARINA    SUL 2023-03-15  4614.0
#
#      diferença_dias
# 3042       441 days
# 4109       441 days
# 4575       441 days
